# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
ramdom_image = np.random.randint(0,256,(100,100,3), dtype=np.uint8)
RGB_image = cv2.cvtColor(ramdom_image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12,4))
plt.imshow(RGB_image)

# %%
image = cv2.imread("C:/Users/USER/Desktop/download.jpg")
plt.figure(figsize=(12,4))
plt.imshow(image)

# %%
image = cv2.imread("C:/Users/USER/Desktop/download.jpg")
RGB_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12,4))
plt.imshow(RGB_image)

# %%
R, G, B = cv2.split(RGB_image)

# %%
plt.figure(figsize=(12,4))

# %%
plt.subplot(1, 3, 1)
plt.imshow(R, cmap='Reds')
plt.title('Red Channel')
# Out:
# Text(0.5, 1.0, 'Red Channel')

# %%
plt.subplot(1, 3, 2)
plt.imshow(G, cmap='Greens')
plt.title('Green Channel')
# Out:
# Text(0.5, 1.0, 'Green Channel')

# %%
plt.subplot(1, 3, 3)
plt.imshow(B, cmap='Blues')
plt.title('Blue Channel')
# Out:
# Text(0.5, 1.0, 'Blue Channel')

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_hsv = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2HSV)

H, S, V = cv2.split(image_hsv)

plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.imshow(H, cmap='hsv')
plt.title('Hue Channel')
    
plt.subplot(1, 3, 2)
plt.imshow(S, cmap='gray')
plt.title('Saturation Channel')
    
plt.subplot(1, 3, 3)
plt.imshow(V, cmap='gray')
plt.title('Value Channel')
    
plt.show()

# %%
RGB_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
resized_image = cv2.resize(RGB_image, (64, 64))
plt.imshow(resized_image)

# %%
RGB_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
resized_image = cv2.resize(RGB_image, (64, 64), interpolation=cv2.INTER_AREA)
plt.imshow(resized_image)
